# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv




# Import API key
import api_keys 
from api_keys import api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
#output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 595

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#get API key
api_key = api_keys.api_key

#URL for Weather Map API
url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=" + api_key


# Save config information.
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{base_url}appid={api_key}&units={units}&q="
query_url

# set up lists to hold the response data

temperature = []
humidity = []
cloudiness = []
windspeed = []
lat = []
lng = []
country = []
date = []
place = []

count = 0
print('Beginning Data Retrieval')    
print('-----------------------------')

# Loop through the list of cities and perform a request for data on each
for city in cities:
    count = count + 1
    try:
        print("Processing Record {} of Set 1 | {}".format(count,city))
        response = requests.get(query_url + city).json()
#         print(json.dumps(response,indent=4))
#         break
        place.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temperature.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        windspeed.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        #print(json.dumps(response,indent=4))
        
    except KeyError:
        print("City not found. Skipping...")
print('-----------------------------')
print('Data Retrieval Complete')      
print('-----------------------------')        
# print(len(place))
# print(len(lat))
# print(len(lng))
# print(len(temp))
# print(len(humidity))
# print(len(wind))
# print(len(cloudiness))
# print(len(country))
# print(len(date))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | warrnambool
# Processing Record 3 of Set 1 | pampierstad
# Processing Record 4 of Set 1 | salalah
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | buckeye
# Processing Record 9 of Set 1 | etchoropo
# Processing Record 10 of Set 1 | la ronge
# Processing Record 11 of Set 1 | launceston
# Processing Record 12 of Set 1 | te anau
# Processing Record 13 of Set 1 | nova petropolis
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | lagos
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | tabou
# Processing Record 18 of Set 1 | grindavik
# Processing Record 19 of Set 1 | north bend
# Processing Record 20 of Set 1 | vardo
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | peleduy
# Processing Record 24 of Set 1 | maldonado
# Processing Record 25 of Set 1 | ahipara
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | praia da vitoria
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | bontang
# Processing Record 30 of Set 1 | viedma
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | paamiut
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | falaleu
# City not found. Skipping...
# Processing Record 39 of Set 1 | victoria
# Processing Record 40 of Set 1 | smithers
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | port macquarie
# Processing Record 48 of Set 1 | coquimbo
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 51 of Set 1 | juneau
# Processing Record 52 of Set 1 | busselton
# Processing Record 53 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 54 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 55 of Set 1 | jamestown
# Processing Record 56 of Set 1 | castro
# Processing Record 57 of Set 1 | carnarvon
# Processing Record 58 of Set 1 | college
# Processing Record 59 of Set 1 | buala
# Processing Record 60 of Set 1 | atuona
# Processing Record 61 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 62 of Set 1 | bubaque
# Processing Record 63 of Set 1 | camacari
# Processing Record 64 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 65 of Set 1 | hami
# Processing Record 66 of Set 1 | port hardy
# Processing Record 67 of Set 1 | vaini
# Processing Record 68 of Set 1 | ribas do rio pardo
# Processing Record 69 of Set 1 | dolores
# Processing Record 70 of Set 1 | jaena
# Processing Record 71 of Set 1 | butaritari
# Processing Record 72 of Set 1 | la palma
# Processing Record 73 of Set 1 | campbellton
# Processing Record 74 of Set 1 | kolokani
# Processing Record 75 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 76 of Set 1 | vila franca do campo
# Processing Record 77 of Set 1 | zhicheng
# Processing Record 78 of Set 1 | nikolskoye
# Processing Record 79 of Set 1 | talnakh
# Processing Record 80 of Set 1 | cay
# Processing Record 81 of Set 1 | guerrero negro
# Processing Record 82 of Set 1 | obluche
# City not found. Skipping...
# Processing Record 83 of Set 1 | katsuura
# Processing Record 84 of Set 1 | chokurdakh
# Processing Record 85 of Set 1 | ushuaia
# Processing Record 86 of Set 1 | le pradet
# Processing Record 87 of Set 1 | jaque
# City not found. Skipping...
# Processing Record 88 of Set 1 | kaduqli
# Processing Record 89 of Set 1 | tigil
# Processing Record 90 of Set 1 | ode
| pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 399 of Set 1 | halifax
# Processing Record 400 of Set 1 | chicama
# Processing Record 401 of Set 1 | pilar
# Processing Record 402 of Set 1 | avera
# Processing Record 403 of Set 1 | nsanje
# Processing Record 404 of Set 1 | tricase
# Processing Record 405 of Set 1 | poum
# Processing Record 406 of Set 1 | bandar-e lengeh
# Processing Record 407 of Set 1 | pahrump
# Processing Record 408 of Set 1 | tugulym
# Processing Record 409 of Set 1 | ayni
# Processing Record 410 of Set 1 | ibra
# Processing Record 411 of Set 1 | kieta
# Processing Record 412 of Set 1 | kaputa
# Processing Record 413 of Set 1 | quang ngai
# Processing Record 414 of Set 1 | geresk
# City not found. Skipping...
# Processing Record 415 of Set 1 | sisimiut
# Processing Record 416 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 417 of Set 1 | luanda
# Processing Record 418 of Set 1 | karratha
# Processing Record 419 of Set 1 | agirish
# Processing Record 420 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 421 of Set 1 | yulara
# Processing Record 422 of Set 1 | atar
# Processing Record 423 of Set 1 | panama city
# Processing Record 424 of Set 1 | sandviken
# Processing Record 425 of Set 1 | hudson bay
# Processing Record 426 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 427 of Set 1 | pontianak
# Processing Record 428 of Set 1 | dongsheng
# Processing Record 429 of Set 1 | faya
# Processing Record 430 of Set 1 | mahajanga
# Processing Record 431 of Set 1 | gezing
# Processing Record 432 of Set 1 | haicheng
# Processing Record 433 of Set 1 | pisco
# Processing Record 434 of Set 1 | lengshuitan
# Processing Record 435 of Set 1 | novopokrovka
# Processing Record 436 of Set 1 | mount gambier
# Processing Record 437 of Set 1 | neiafu
# Processing Record 438 of Set 1 | fort abbas
# Processing Record 439 of Set 1 | auki
# Processing Record 440 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 441 of Set 1 | bandarbeyla
# Processing Record 442 of Set 1 | bani walid
# Processing Record 443 of Set 1 | zhezkazgan
# Processing Record 444 of Set 1 | oia
# Processing Record 445 of Set 1 | fort nelson
# Processing Record 446 of Set 1 | zhoucheng
# Processing Record 447 of Set 1 | gunjur
# Processing Record 448 of Set 1 | zbarazh
# Processing Record 449 of Set 1 | haines junction
# Processing Record 450 of Set 1 | portland
# Processing Record 451 of Set 1 | longyan
# Processing Record 452 of Set 1 | khani
# Processing Record 453 of Set 1 | mahibadhoo
# Processing Record 454 of Set 1 | camana
# City not found. Skipping...
# Processing Record 455 of Set 1 | salisbury
# Processing Record 456 of Set 1 | levashovo
# Processing Record 457 of Set 1 | lamu
# Processing Record 458 of Set 1 | kiama
# Processing Record 459 of Set 1 | chunoyar
# Processing Record 460 of Set 1 | tombouctou
# Processing Record 461 of Set 1 | shache
# Processing Record 462 of Set 1 | pemangkat
# City not found. Skipping...
# Processing Record 463 of Set 1 | taraz
# Processing Record 464 of Set 1 | ingham
# Processing Record 465 of Set 1 | adrar
# Processing Record 466 of Set 1 | ixtapa
# Processing Record 467 of Set 1 | port-gentil
# Processing Record 468 of Set 1 | ilek
# Processing Record 469 of Set 1 | teruel
# Processing Record 470 of Set 1 | los llanos de aridane
# Processing Record 471 of Set 1 | san andres
# Processing Record 472 of Set 1 | krasnoshchekovo
# Processing Record 473 of Set 1 | provost
# Processing Record 474 of Set 1 | tsentralnyy-kospashskiy
# City not found. Skipping...
# Processing Record 475 of Set 1 | crotone
# Processing Record 476 of Set 1 | amapa
# Processing Record 477 of Set 1 | kuzhener
# Processing Record 478 of Set 1 | hobyo
# Processing Record 479 of Set 1 | bayan
# Processing Record 480 of Set 1 | tvoroyri
# Processing Record 481 of Set 1 | umm lajj
# Processing Record 482 of Set 1 | walvis bay
# Processing Record 483 of Set 1 | perth
# Processing Record 484 of Set 1 | toktogul
# Processing Record 485 of Set 1 | bettiah
# Processing Record 486 of Set 1 | zhigansk
# Processing Record 487 of Set 1 | saint george
# Processing Record 488 of Set 1 | chandbali
# Processing Record 489 of Set 1 | komsomolskiy
# Processing Record 490 of Set 1 | kastamonu
# Processing Record 491 of Set 1 | kirakira
# Processing Record 492 of Set 1 | yarkovo
# Processing Record 493 of Set 1 | inhambane
# Processing Record 494 of Set 1 | hoquiam
# Processing Record 495 of Set 1 | monrovia
# Processing Record 496 of Set 1 | emba
# Processing Record 497 of Set 1 | bethel
# Processing Record 498 of Set 1 | mutsu
# Processing Record 499 of Set 1 | westport
# Processing Record 500 of Set 1 | hun
# Processing Record 501 of Set 1 | bac lieu
# City not found. Skipping...
# Processing Record 502 of Set 1 | fomboni
# Processing Record 503 of Set 1 | townsville
# Processing Record 504 of Set 1 | port keats
# Processing Record 505 of Set 1 | mahanoro
# Processing Record 506 of Set 1 | biak
# Processing Record 507 of Set 1 | sabha
# Processing Record 508 of Set 1 | guangyuan
# Processing Record 509 of Set 1 | kosh-agach
# Processing Record 510 of Set 1 | buchanan
# Processing Record 511 of Set 1 | oudtshoorn
# Processing Record 512 of Set 1 | nouadhibou
# Processing Record 513 of Set 1 | pokhara
# Processing Record 514 of Set 1 | hampton
# Processing Record 515 of Set 1 | namibe
# Processing Record 516 of Set 1 | asau
# City not found. Skipping...
# Processing Record 517 of Set 1 | san pedro buenavista
# Processing Record 518 of Set 1 | oster
# Processing Record 519 of Set 1 | melbu
# Processing Record 520 of Set 1 | shahr-e babak
# Processing Record 521 of Set 1 | mahenge
# Processing Record 522 of Set 1 | dodge city
# Processing Record 523 of Set 1 | tura
# Processing Record 524 of Set 1 | namatanai
# Processing Record 525 of Set 1 | riyadh
# Processing Record 526 of Set 1 | airai
# Processing Record 527 of Set 1 | itacoatiara
# Processing Record 528 of Set 1 | tazovskiy
# Processing Record 529 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 530 of Set 1 | katangli
# Processing Record 531 of Set 1 | san carlos
# Processing Record 532 of Set 1 | safaqis
# City not found. Skipping...
# Processing Record 533 of Set 1 | boone
# Processing Record 534 of Set 1 | fortuna
# Processing Record 535 of Set 1 | lasa
# Processing Record 536 of Set 1 | puteyets
# Processing Record 537 of Set 1 | paratinga
# Processing Record 538 of Set 1 | tanout
# Processing Record 539 of Set 1 | chitral
# Processing Record 540 of Set 1 | carballo
# Processing Record 541 of Set 1 | ende
# Processing Record 542 of Set 1 | yunjinghong
# City not found. Skipping...
# Processing Record 543 of Set 1 | marzuq
# Processing Record 544 of Set 1 | sayhat
# Processing Record 545 of Set 1 | vaovai
# City not found. Skipping...
# Processing Record 546 of Set 1 | saint-augustin
# Processing Record 547 of Set 1 | kupang
# Processing Record 548 of Set 1 | batemans bay
# Processing Record 549 of Set 1 | richards bay
# Processing Record 550 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record 551 of Set 1 | sechura
# Processing Record 552 of Set 1 | maoming
# Processing Record 553 of Set 1 | intipuca
# Processing Record 554 of Set 1 | vostok
# Processing Record 555 of Set 1 | sao felix do xingu
# Processing Record 556 of Set 1 | lashio
# Processing Record 557 of Set 1 | wabana
# Processing Record 558 of Set 1 | ngama
# City not found. Skipping...
# Processing Record 559 of Set 1 | saint-joseph
# Processing Record 560 of Set 1 | honningsvag
# Processing Record 561 of Set 1 | dogondoutchi
# Processing Record 562 of Set 1 | mount isa
# Processing Record 563 of Set 1 | luderitz
# Processing Record 564 of Set 1 | xining
# Processing Record 565 of Set 1 | sao filipe
# Processing Record 566 of Set 1 | vallenar
# Processing Record 567 of Set 1 | ambilobe
# Processing Record 568 of Set 1 | madras
# Processing Record 569 of Set 1 | troitskoye
# Processing Record 570 of Set 1 | santa vitoria
# Processing Record 571 of Set 1 | eqbaliyeh
# Processing Record 572 of Set 1 | moree
# Processing Record 573 of Set 1 | paraiso
# Processing Record 574 of Set 1 | orgun
# City not found. Skipping...
# Processing Record 575 of Set 1 | chardara
# City not found. Skipping...
# Processing Record 576 of Set 1 | mayya
# Processing Record 577 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 578 of Set 1 | sistranda
# Processing Record 579 of Set 1 | plettenberg bay
# Processing Record 580 of Set 1 | neya
# Processing Record 581 of Set 1 | shingu
# Processing Record 582 of Set 1 | ust-nera
# Processing Record 583 of Set 1 | qiqihar
# Processing Record 584 of Set 1 | coihaique
# Processing Record 585 of Set 1 | hvide sande
# Processing Record 586 of Set 1 | belyy yar
# Processing Record 587 of Set 1 | yatou
# Processing Record 588 of Set 1 | cayce
# Processing Record 589 of Set 1 | nizwa
# Processing Record 590 of Set 1 | marion
# Processing Record 591 of Set 1 | carbondale
# Processing Record 592 of Set 1 | mbandaka
# Processing Record 593 of Set 1 | vilcun
# Processing Record 594 of Set 1 | makakilo city
# Processing Record 595 of Set 1 | petropavlovsk-kamchatskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create a dataframe with required items
weather_df = { 'City' : place,
             'Latitude' : lat,
             'Longitude' : lng,
             'Max Temperture' : temperature,
             'Humidity' : humidity,
             'Cloud coverage' : cloudiness,
             'Wind Speed' : windspeed,
             'Country' : country,
             'DateTime' : date,
}

# Display the DataFrame
new_weather_df = pd.DataFrame(weather_df)
new_weather_df.head()
# Out:
#           City  Latitude  Longitude  Max Temperture  Humidity  Cloud coverage  \
# 0      Rikitea    -23.12    -134.97           23.25        72              97
# 1  Warrnambool    -38.38     142.48           13.33        78              92
# 2  Pampierstad    -27.78      24.69           26.92        37              18
# 3      Salalah     17.01      54.10           27.00        69              20
# 4    Upernavik     72.79     -56.15           -8.89        67              75
#
#    Wind Speed Country    DateTime
# 0        5.84      PF  1573361384
# 1        4.02      AU  1573361384
# 2        8.72      ZA  1573361385
# 3        0.50      OM  1573361385
# 4        1.25      GL  1573361385

# %%
save dataframe as csv
new_weather_df.to_csv(output_data_file, index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Latitude vs. Temperature Plot
plt.scatter(lat, temperature, marker="o", facecolors="c", edgecolors="black")
plt.title("City Latitude vs. Max Temperature ({})" .format(date1))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("LatitudevsTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Latitude vs. Humidity Plot

plt.scatter(lat,humidity,marker="o", edgecolors="black")
plt.title("City Latitude vs. Humidity ({})" .format(date1))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.savefig("LatitudevsHumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Latitude vs. Cloudiness Plot

plt.scatter(lat,cloudiness,marker="o", facecolors="blue", edgecolors="black")
plt.title("City Latitude vs. Cloudiness ({})" .format(date1))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.savefig("LatitudevsCloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Latitude vs. Wind Speed Plot

plt.scatter(lat,windspeed,marker="o", facecolors="green", edgecolors="black")
plt.title("City Latitude vs. Wind Speed ({})" .format(date1))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.savefig("LatitudevsWind.png")
